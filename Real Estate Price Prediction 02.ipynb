# %%
import pandas as pd
import numpy as np

# %%
ds_path_test='test.csv'
ds_path_train='test.csv' # тут совершаем подмену для подготовки тестового датасета!!!!

# %%
df_test=pd.read_csv(ds_path_test)
df_test
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0       725          58    2.0  49.882643   33.432782            6.0      6
# 1     15856          74    2.0  69.263183         NaN            1.0      6
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 3     15664          47    2.0  73.046609   51.940842            9.0     22
# 4     14275          27    1.0  47.527111   43.387569            1.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
# ...

# %%
df_train=pd.read_csv(ds_path_train)
df_train
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0       725          58    2.0  49.882643   33.432782            6.0      6
# 1     15856          74    2.0  69.263183         NaN            1.0      6
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 3     15664          47    2.0  73.046609   51.940842            9.0     22
# 4     14275          27    1.0  47.527111   43.387569            1.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
# ...

# %%
price=df_train.Price
price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-7e6855d3d65d> in <module>
# ----> 1 price=df_train.Price
#       2 price
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Price'

# %%
fiature_names=df_train.columns.usecols = ['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
       'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
       'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
       'Helthcare_2', 'Shops_1', 'Shops_2']
fiature_names
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2'],
#       dtype='object')

# %%
x = pd.DataFrame(df_train, columns=fiature_names)
x
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0       725          58    2.0  49.882643   33.432782            6.0      6
# 1     15856          74    2.0  69.263183         NaN            1.0      6
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 3     15664          47    2.0  73.046609   51.940842            9.0     22
# 4     14275          27    1.0  47.527111   43.387569            1.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       5000 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     5000 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# A                5000 non-null uint8
# B                5000 non-null uint8
# A                5000 non-null uint8
# B                5000 non-null uint8
# A                5000 non-null uint8
# B                5000 non-null uint8
# ...

# %%
x.describe().T
# Out:
#                 count         mean          std          min          25%  \
# Id             5000.0  8412.595400  4832.674037     1.000000  4221.750000
# DistrictId     5000.0    51.279200    44.179466     0.000000    21.000000
# Rooms          5000.0     1.910000     0.838594     0.000000     1.000000
# Square         5000.0    56.449500    19.092787     1.378543    41.906231
# LifeSquare     3959.0    36.158810    17.825287     0.333490    23.092026
# KitchenSquare  5000.0     5.976800     9.950018     0.000000     1.000000
# Floor          5000.0     8.632000     5.483228     1.000000     4.000000
# HouseFloor     5000.0    12.601000     6.789213     0.000000     9.000000
# HouseYear      5000.0  1984.392600    18.573149  1908.000000  1973.000000
# Ecology_1      5000.0     0.119874     0.120070     0.000000     0.019509
# Social_1       5000.0    24.933800    17.532202     0.000000     6.000000
# Social_2       5000.0  5406.900000  4026.614773   168.000000  1564.000000
# ...

# %%
print(x['Ecology_2'].value_counts())
# Out:
# B    4952
# A      48
# Name: Ecology_2, dtype: int64

# %%
print(x['Ecology_3'].value_counts())
# Out:
# B    4851
# A     149
# Name: Ecology_3, dtype: int64

# %%
print(x['Shops_2'].value_counts())
# Out:
# B    4588
# A     412
# Name: Shops_2, dtype: int64

# %%
# dummy кодирование
x=pd.concat([x,pd.get_dummies(x['Ecology_2'])],axis=1)

# %%
# dummy кодирование
x=pd.concat([x,pd.get_dummies(x['Ecology_3'])],axis=1)

# %%
# dummy кодирование
x=pd.concat([x,pd.get_dummies(x['Shops_2'])],axis=1)

# %%
del x['Ecology_2']
del x['Ecology_3']
del x['Shops_2']

# %%
x.head().T
# Out:
#                          0             1            2             3  \
# Id              725.000000  15856.000000  5480.000000  15664.000000
# DistrictId       58.000000     74.000000   190.000000     47.000000
# Rooms             2.000000      2.000000     1.000000      2.000000
# Square           49.882643     69.263183    13.597819     73.046609
# LifeSquare       33.432782           NaN    15.948246     51.940842
# KitchenSquare     6.000000      1.000000    12.000000      9.000000
# Floor             6.000000      6.000000     2.000000     22.000000
# HouseFloor       14.000000      1.000000     5.000000     22.000000
# HouseYear      1972.000000   1977.000000  1909.000000   2007.000000
# Ecology_1         0.310199      0.075779     0.000000      0.101872
# Social_1         11.000000      6.000000    30.000000     23.000000
# Social_2       2748.000000   1437.000000  7538.000000   4583.000000
# Social_3          1.000000      3.000000    87.000000      3.000000
# ...

# %%
# заменим нули на медиану
x.loc[x['Healthcare_1'].isnull(),'Healthcare_1']=x['Healthcare_1'].median()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
l = [i for i in range(5000)]
plt.plot(l,x['Healthcare_1'].values)
plt.show()

# %%
plt.plot(l,x['LifeSquare'].values)
plt.show()

# %%
# получим ИНДЕКСЫ всех выбросов жилой площади (взял пять медиан, хотя этот момент надо проанализировать, 
# бывают же очень большие квартиры)
wrong_values_LifeSquare=x[x.LifeSquare > x['LifeSquare'].median()*5][['LifeSquare']].index
wrong_values_LifeSquare
# Out:
# Int64Index([410, 2557], dtype='int64')

# %%
# самый жоский выброс:
x.loc[4328,'LifeSquare']
# Out:
# 24.712248471046475

# %%
mode_l=x['LifeSquare'].median()
mode_l
# Out:
# 32.92508663208161

# %%
# заменим выбросы на медиану
x.loc[x[x.LifeSquare > x['LifeSquare'].median()*5][['LifeSquare']].index,'LifeSquare']=x['LifeSquare'].median()

# %%
# заменим нули на медиану
x.loc[x['LifeSquare'].isnull(),'LifeSquare']=x['LifeSquare'].median()

# %% [markdown]
# Id - идентификационный номер квартиры
# DistrictId - идентификационный номер района
# Rooms - количество комнат
# Square - площадь
# LifeSquare - жилая площадь
# KitchenSquare - площадь кухни
# Floor - этаж
# HouseFloor - количество этажей в доме
# HouseYear - год постройки дома
# Ecology_1, Ecology_2, Ecology_3 - экологические показатели местности
# Social_1, Social_2, Social_3 - социальные показатели местности
# Healthcare_1, Helthcare_2 - показатели местности, связанные с охраной здоровья
# Shops_1, Shops_2 - показатели, связанные с наличием магазинов, торговых центров
# Price - цена квартиры

# %%
y=pd.DataFrame(price, columns=['Price'])
y
# Out:
#               Price
# 0     184966.930730
# 1     300009.450063
# 2     220925.908524
# 3     175616.227217
# 4     150226.531644
# ...             ...
# 9995  196684.316040
# 9996  189050.289571
# 9997  159143.805370
# 9998  181595.339808
# 9999  218714.077615
#
# [10000 rows x 1 columns]

# %%
# сохранить обработанные данные в массив
x.to_csv('ttest_prepared_01.csv')
